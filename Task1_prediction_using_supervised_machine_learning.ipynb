# %% [markdown]
# # THE SPARKS FOUNDATION

# %% [markdown]
# # GRADUATE ROTATIONAL INTERNSHIP PROGRAM - GRIP

# %% [markdown]
# # Data Science and Business Analytics intern

# %% [markdown]
# # AUTHOR: Akshay Ravella

# %% [markdown]
# # Task1: Prediction using Supervised Machine Learning

# %%
#importing required libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importing and reading the dataset
df=pd.read_csv("https://raw.githubusercontent.com/AdiPersonalWorks/Random/master/student_scores%20-%20student_scores.csv")
df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %% [markdown]
# head() function prints first 5 rows of the data set

# %%
#summary of the given dataset
df.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %%
df.shape
# Out:
# (25, 2)

# %%
#check if there are any missing values in the dataset
df.isnull==True
# Out:
# False

# %%
# data visualization
plt.scatter(df["Hours"],df["Scores"])
plt.xlabel("Hours")
plt.ylabel("Scores")
plt.title(" Hours Studied VS Scores Obtained")
plt.show()

# %%
sns.regplot(x= df['Hours'], y= df['Scores'])
plt.title('Regression Plot',size=20)
plt.ylabel('Marks Percentage', size=12)
plt.xlabel('Hours Studied', size=12)
plt.show()
print(df.corr())
# Out:
#            Hours    Scores
# Hours   1.000000  0.976191
# Scores  0.976191  1.000000

# %% [markdown]
# It is positively correlated

# %%
#Defining X and y from the Data
#X will take all the values except for the last column which is our dependent variable (target variable)
X=df.iloc[:,:-1].values
Y=df.iloc[:, -1].values

# %%
#using train_test_split from sklearn.model_selection to split the training and testing dataset
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=100)

# %%
#fitting the data to the model
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
#predicting the test set and train set result
pred_Y= regressor.predict(X_test)
print(pred_Y)
pred_X= regressor.predict(X_train)
print(pred_X)
# Out:
# [28.14877107 39.00765694 34.07179972 59.73825724 16.30271375 74.54582888
#  69.60997167 48.87937137]
# [92.31491485 45.91785704 36.04614261 78.49451465 26.17442818 51.84088569
#  28.14877107 12.35402798 20.25139952 61.71260012 33.08462828 77.50734321
#  26.17442818 89.35340052 55.78957147 85.40471475 83.43037187]

# %%
#visualizing training data set
plt.scatter(X_train,Y_train,color="red")
plt.plot(X_train,pred_X,color="black")
plt.xlabel("HOURS")
plt.ylabel("SCORES")
plt.title("HOURS VS SCORES")
plt.show()

# %%
#visualizing test data set
plt.scatter(X_test,Y_test,color="red")
plt.plot(X_train,pred_X,color="black")
plt.xlabel("HOURS")
plt.ylabel("SCORES")
plt.title("HOURS VS SCORES")
plt.show()

# %%
#printing predicted scores
prediction=pd.DataFrame({"hours":[i[0] for i in X_test],"predicted marks":[k for k in pred_Y]})
print(prediction)
# Out:
#    hours  predicted marks
# 0    2.7        28.148771
# 1    3.8        39.007657
# 2    3.3        34.071800
# 3    5.9        59.738257
# 4    1.5        16.302714
# 5    7.4        74.545829
# 6    6.9        69.609972
# 7    4.8        48.879371

# %%
#comparing actual and predicted marks
com=pd.DataFrame({"Actual":Y_test,"Predicted":pred_Y})
print(com)
# Out:
#    Actual  Predicted
# 0      25  28.148771
# 1      35  39.007657
# 2      42  34.071800
# 3      62  59.738257
# 4      20  16.302714
# 5      69  74.545829
# 6      76  69.609972
# 7      54  48.879371

# %%
#visualizing actual and predicted values
plt.scatter(x=X_test, y=Y_test, color='blue')
plt.plot(X_test, pred_Y, color='Black')
plt.title('Actual vs Predicted', size=20)
plt.ylabel('Score obtained', size=12)
plt.xlabel('Hours Studied', size=12)
plt.show()

# %%
# Calculating the accuracy of the model
from sklearn.metrics import mean_absolute_error
print('Mean absolute error: ',mean_absolute_error(Y_test,pred_Y))
# Out:
# Mean absolute error:  4.762517892332275

# %% [markdown]
# since error is minimal so model will give accurate value to a good extent

# %% [markdown]
# # What will be the predicted score of a student if he/she studies for 9.25 hrs/ day?

# %%
hours = [9.25]
answer = regressor.predict([hours])
print("Score = {}".format(answer))
# Out:
# Score = [92.80850057]

# %% [markdown]
# if the student studies for 9.25 hrs/ day he/she will approximately score 92.8%
